# %% [markdown]
# ##外積
#
# **学習目標**：ベクトル積は2種類あり、内積（Inner Product, Scalar Product）と外積（Outer Product, Vector Product）の結果と意味、活用に大きな違いがあることをしっかり理解しましょう。
#
# 特に、内積は機械学習において、使用頻度が高く、ベクトル同士の類似度を計算するために使用するコサイン類似度とも密接に関係します。そのあたりも意識して理解を深めるようにしましょう。
#
# 任意のベクトル$\mathbf{a}$と$\mathbf{b}$の外積は次式のように定義される。
#
# $$\mathbf{a}\times\mathbf{b}= \|\mathbf{a}\|\|\mathbf{b}\|\sin{\theta} $$
#
# ベクトル$\mathbf{a}$と$\mathbf{b}$が次のように与えられたら
#
# $$ \mathbf{a}= \begin{bmatrix}
#  1 \\ 3 \\
# \end{bmatrix} , \mathbf{b}= \begin{bmatrix}
#  5 \\ 1 \\
# \end{bmatrix} $$
#
# 外積の結果は次のようになります。

# %%
import numpy as np
import matplotlib.pyplot as plt

# ベクトルの定義
a = np.array([1, 3])
b = np.array([5, 1])

# 外積の計算 (2Dベクトルの場合、スカラー値になります)
cross_product = np.cross(a, b)

# プロットの設定
plt.figure(figsize=(8, 6))
plt.axhline(y=0, color='k', linestyle='--')
plt.axvline(x=0, color='k', linestyle='--')

# ベクトルの描画
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='r', label='a')
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='b', label='b')

# 射影ベクトルからベクトルaの先端までの垂線を描画
plt.plot([projection_ab[0], a[0]], [projection_ab[1], a[1]], 'k--', color='g', label='Perpendicular from projection to a')

# 平行四辺形の描画
plt.fill([0, a[0], a[0]+b[0], b[0]], [0, a[1], a[1]+b[1], b[1]], 'lightgray', alpha=0.5)

# プロットの範囲設定
plt.xlim(-1, 7)
plt.ylim(-1, 5)

# ラベルと凡例の追加
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Corss Product of vector a and b: {cross_product}')
plt.legend()
plt.grid(True)

# 外積の大きさを表示
plt.text(3, 2, f'|a × b| = {abs(cross_product)}', fontsize=12,
         bbox=dict(facecolor='white', alpha=0.5))

# プロットの表示
plt.show()
# Out:
# <ipython-input-7-a8dd6384c72d>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([projection_ab[0], a[0]], [projection_ab[1], a[1]], 'k--', color='g', label='Perpendicular from projection to a')

# %% [markdown]
# 上図に示されているように、外積の結果は2つのベクトルのなす平行四辺形の面積となります。小学校で習った平行四辺形の面積の公式を思い出してもらえば、容易に理解できると思います。
#
# すなわち、長さ$\|\mathbf{a}\|\sin{\theta}$と長さ$\|\mathbf{b}\|$の掛け算になっています。
#
# 次に重要なことは、このベクトル積で得られたベクトルの向きです。これには右手の法則というものが適用されますが、$\mathbf{a}$と$\mathbf{b}$が反時計回りに配置されていれば、結果のベクトルの向きは、これらのベクトルが成す平面から垂直な方向、今回の場合は、平面から手前の方向となります。
